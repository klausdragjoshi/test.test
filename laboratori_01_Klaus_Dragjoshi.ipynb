# %% [markdown]
# # Laboratori 01 – Hyrje në JupyterLab dhe Mjedisin e Punës
#
# *Kursi:* Hyrje në laborator (Fizikë & Shkenca Kompjuterike)
# *Studenti:* Klaus Dragjoshi
# *Data:* 2026-03-16

# %% [markdown]
# ## Qëllimi
#
# Në këtë notebook kam dokumentuar:
#
# 1. *Konfigurimin e "environment"* lab (përmes Conda).
# 2. *Nisjen e JupyterLab* dhe krijimin e një notebook-u të ri.
# 3. *Ekzekutimin e qelizave (cells)* dhe kontrollin bazë të kernel-it.
# 4. *Një test minimal* të funksionimit të librarive kryesore: Python, NumPy dhe Matplotlib.

# %% [markdown]
# ## Lista e kontrollit (Checklist)
#
# * [x] Miniconda/Anaconda i instaluar
# * [x] Mjedisi lab i krijuar
# * [x] JupyterLab nis pa probleme
# * [x] Qelizat e kodit ekzekutohen (Shift+Enter)
# * [x] Notebook-u ruhet dhe ngarkohet në GitHub

# %%
# Test minimal: Python funksionon?
a = 5
b = 3
a + b
# Out:
# 8

# %%
# Importet standarde të kursit
import numpy as np
import matplotlib.pyplot as plt

np.__version__
# Out:
# '2.4.1'

# %%
# Test minimal i NumPy
data = np.array([10.1, 10.2, 9.9, 10.0, 10.3])
mean = np.mean(data)
std_sample = np.std(data, ddof=1)

mean, std_sample
# Out:
# (np.float64(10.1), np.float64(0.15811388300841897))

# %%
# Test minimal i Matplotlib
plt.hist(data, bins=5)
plt.xlabel("Vlera (njësi)")
plt.ylabel("Frekuenca")
plt.title("Histogram test")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Përfundim
#
# *Përgjigje:*
# * Instalimi funksionoi shumë mirë dhe të gjitha libraritë u ngarkuan saktë.
# * JupyterLab u hap pa asnjë vonesë përmes terminalit.
# * Nuk pata gabime kritike gjatë konfigurimit.
# * Dallimi mes Markdown dhe Code është se Markdown shërben për shpjegime tekstuale, ndërsa Code për ekzekutimin e llogaritjeve.
